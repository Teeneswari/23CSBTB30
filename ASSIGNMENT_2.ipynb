# %% [markdown]
# <a href="https://colab.research.google.com/github/Teeneswari/23CSBTB30/blob/main/ASSIGNMENT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
                         ASSIGNMENT-2

# %%
import pandas as pd
data=pd.read_excel("/content/A2.xlsx")
print(data)
df=pd.DataFrame(data,columns=["STUDENTID"])
df
# Out:
#     STUDENTID   STUDENT NAME COURSE NAME    CONT NUM
# 0        2110   R.Teeneswari      B.Tech  6303832053
# 1        2111   A.vaishnavi       B.Tech  9732660752
# 2        2112      T.arsha        B.Tech  9182551624
# 3        2113      V.anushka      B.Tech  9182551624
# 4        2114        G.rithu      B.Tech  9059248722
# 5        2115   Ch.maindeep       B.Tech  8902456738
# 6        2116    M.kavya sri      B.Tech  7304599012
# 7        2117    A.rithika        B.Tech  9059247233
# 8        2118     Ch.sujith       B.Tech  8902487278
# 9        2119          A.Ram      B.Tech  8460927890
# 10       2120       V.sita        B.Tech  9056478562
# 11       2121     A.Harmine       B.Tech  7892467380
# 12       2122       CH.vijay      B.Tech  6307899243
# 13       2123       S.laxmi       B.Tech  9702485608
# 14       2124       T.varun       B.Tech  9395552482
# 15       2125        I.suman      B.Tech  9872567972
# 16       2126        Y.sneha      B.Tech  7089456890
# ...

# %%
import pandas as pd
data=pd.read_csv("/content/A3.csv")
print(data)
df=pd.DataFrame(data,columns=("STUDENTID","COURSE NAME"))
df
# Out:
#     STUDENTID   STUDENT NAME COURSE NAME    CONT NUM
# 0        2110   R.Teeneswari      B.Tech  6303832053
# 1        2111   A.vaishnavi       B.Tech  9732660752
# 2        2112      T.arsha        B.Tech  9182551624
# 3        2113      V.anushka      B.Tech  9182551624
# 4        2114        G.rithu      B.Tech  9059248722
# 5        2115   Ch.maindeep       B.Tech  8902456738
# 6        2116    M.kavya sri      B.Tech  7304599012
# 7        2117    A.rithika        B.Tech  9059247233
# 8        2118     Ch.sujith       B.Tech  8902487278
# 9        2119          A.Ram      B.Tech  8460927890
# 10       2120       V.sita        B.Tech  9056478562
# 11       2121     A.Harmine       B.Tech  7892467380
# 12       2122       CH.vijay      B.Tech  6307899243
# 13       2123       S.laxmi       B.Tech  9702485608
# 14       2124       T.varun       B.Tech  9395552482
# 15       2125        I.suman      B.Tech  9872567972
# 16       2126        Y.sneha      B.Tech  7089456890
# ...

# %%
import pandas as pd
data=pd.read_table("/content/A4.txt")
print(data)
df=pd.DataFrame(data,columns=("STUDENTID","STUDENT NAME","COURSE NAME"))
df
# Out:
#     STUDENTID   STUDENT NAME COURSE NAME    CONT NUM
# 0        2110   R.Teeneswari      B.Tech  6303832053
# 1        2111   A.vaishnavi       B.Tech  9732660752
# 2        2112      T.arsha        B.Tech  9182551624
# 3        2113      V.anushka      B.Tech  9182551624
# 4        2114        G.rithu      B.Tech  9059248722
# 5        2115   Ch.maindeep       B.Tech  8902456738
# 6        2116    M.kavya sri      B.Tech  7304599012
# 7        2117    A.rithika        B.Tech  9059247233
# 8        2118     Ch.sujith       B.Tech  8902487278
# 9        2119          A.Ram      B.Tech  8460927890
# 10       2120       V.sita        B.Tech  9056478562
# 11       2121     A.Harmine       B.Tech  7892467380
# 12       2122       CH.vijay      B.Tech  6307899243
# 13       2123       S.laxmi       B.Tech  9702485608
# 14       2124       T.varun       B.Tech  9395552482
# 15       2125        I.suman      B.Tech  9872567972
# 16       2126        Y.sneha      B.Tech  7089456890
# ...

# %%
import pandas as pd
data=pd.read_csv("/content/heart.csv")
print(data)
df=pd.DataFrame(data,columns=("age","chol"))
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
import pandas as pd
data=pd.read_csv("/content/gamesdata.csv")
print(data)
df=pd.DataFrame(data,columns=("Game Name","Genre"))
df
# Out:
#                                     Game Name       Genre         Platform  \
# 0                   Sekiro: Shadows Die Twice      Sports  Nintendo Switch
# 1                                     Control      Puzzle  Nintendo Switch
# 2                                    Among Us    Strategy  Nintendo Switch
# 3                Call of Duty: Modern Warfare     Stealth      PlayStation
# 4                           League of Legends  Simulation               PC
# ...                                       ...         ...              ...
# 4995  The Legend of Zelda: Breath of the Wild      Sports               PC
# 4996                Assassin's Creed Valhalla     Stealth           Mobile
# 4997             Fall Guys: Ultimate Knockout      Sports           Mobile
# 4998                            Borderlands 3  Platformer             Xbox
# 4999         Counter-Strike: Global Offensive      Action      PlayStation
#
#       Release Year  User Rating
# 0             2014     9.654719
# ...
